# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport

# %%
def importar() -> list:
    dados = pd.read_csv('./online_shoppers_intention.csv')
    return dados.loc[:,['Weekend','VisitorType','TrafficType','Region','Browser','Month','Revenue','ProductRelated_Duration']]

# %%
df = importar()
df.head()
# Out:
#    Weekend        VisitorType  TrafficType  Region  Browser Month  Revenue  \
# 0    False  Returning_Visitor            1       1        1   Feb    False
# 1    False  Returning_Visitor            2       1        2   Feb    False
# 2    False  Returning_Visitor            3       9        1   Feb    False
# 3    False  Returning_Visitor            4       2        2   Feb    False
# 4     True  Returning_Visitor            4       1        3   Feb    False
#
#    ProductRelated_Duration
# 0                 0.000000
# 1                64.000000
# 2                 0.000000
# 3                 2.666667
# 4               627.500000

# %% [markdown]
# <font color='blue'> Sem dúvida, a biblioteca ProfileReport, ajuda muito na análise inicial dos dados, com informações sobre os dados.

# %%
profile = ProfileReport(df, title='Sumário Acesso ao Site', minimal=True)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-01-02 01:24:17.666251&quot;&gt;&lt;title&gt;Sumário Acesso ao Site&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
