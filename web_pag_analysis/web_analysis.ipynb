# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def importar() -> list:
    dados = pd.read_csv('./online_shoppers_intention.csv')
    return dados.loc[:,['Weekend','VisitorType','TrafficType','Region','Browser','Month','Revenue','ProductRelated_Duration']]

# %%
importar()
# Out:
#        Weekend        VisitorType  TrafficType  Region  Browser Month  \
# 0        False  Returning_Visitor            1       1        1   Feb
# 1        False  Returning_Visitor            2       1        2   Feb
# 2        False  Returning_Visitor            3       9        1   Feb
# 3        False  Returning_Visitor            4       2        2   Feb
# 4         True  Returning_Visitor            4       1        3   Feb
# ...        ...                ...          ...     ...      ...   ...
# 12325     True  Returning_Visitor            1       1        6   Dec
# 12326     True  Returning_Visitor            8       1        2   Nov
# 12327     True  Returning_Visitor           13       1        2   Nov
# 12328    False  Returning_Visitor           11       3        2   Nov
# 12329     True        New_Visitor            2       1        2   Nov
#
#        Revenue  ProductRelated_Duration
# 0        False                 0.000000
# 1        False                64.000000
# ...

# %%
# Filtros - Weekend, Month, Região.
