# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder

df = pd.read_csv("C:\\Users\\alcid\\GitHub\\Portfolio\\EBAC\\Dados\\previsao_de_renda.csv")
df = df.drop(axis=0,columns=[df.columns[0]])
ID = df.pop('index')

# %%
def barra_avaliacao() -> None:
    figura = plt.figure(figsize=(15,25))
    figura.suptitle('Avaliação qualitativa dos dados em função do tempo', fontsize=30)
    tamanho = (4,2)
    figura.subplots_adjust(top =   0.91, # Espaço entre o título e os gráficos
                           wspace = 0.7, # Espaço vertical entre os gráficos
                           hspace = 0.5) # Espaço horizontal entre os gráficos
    
    dt = df.select_dtypes(exclude=np.number)
    elementos = dt.columns[1:]
    alvo = 'data_ref'
    contagem = 0 
    for linha in range(4):
        for coluna in range(2):
            pos = (linha, coluna)
            ax = plt.subplot2grid(tamanho, pos)
            atributo = elementos[contagem]
            barra = sns.countplot(x=df[alvo], hue=df[atributo], ax=ax)
            barra.set_title(f'{atributo}', fontsize=15)
            plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
            plt.xticks(rotation=45, horizontalalignment='right')
            contagem += 1
            
    return plt.show()


barra_avaliacao()

# %% [markdown]
# * Avaliando os dados acima, percebe-se que houve uma mudança na distribuição das classes ao longo do tempo, mais especificamente no atributo educação. Na data 2015-09-01 a porcentagem de superior completo aumenta e começa a se manter.

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
def barra_avaliacao() -> None:
    figura = plt.figure(figsize=(15,25))
    figura.suptitle('Avaliação qualitativa dos dados em função do tempo', fontsize=30)
    tamanho = (4,2)
    figura.subplots_adjust(top =   0.91, # Espaço entre o título e os gráficos
                           wspace = 0.7, # Espaço vertical entre os gráficos
                           hspace = 0.5) # Espaço horizontal entre os gráficos
    
    dt = df.select_dtypes(exclude=np.number)
    elementos = dt.columns[1:]
    alvo = 'data_ref'
    contagem = 0 
    for linha in range(4):
        for coluna in range(2):
            pos = (linha, coluna)
            ax = plt.subplot2grid(tamanho, pos)
            atributo = elementos[contagem]
            point = sns.pointplot(x = df[alvo], y = df['renda'] ,hue = df[atributo])
            point.set_title(f'{atributo}', fontsize=15)
            plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
            plt.xticks(rotation=45, horizontalalignment='right')
            contagem += 1
            
    return plt.show()


barra_avaliacao()

# %% [markdown]
# * Observa-se quebra na estabilidade em 3 atributos: Educação, posse de imovel e posse de veículo
