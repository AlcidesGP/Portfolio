# %% [markdown]
# # Sumário
#
# # Explicação
#
# # Metadados
#
# # Objetivos

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import graficos # Biblioteca criada limpar e agilizar a análise dos dados.

from sklearn.preprocessing import LabelEncoder

# %%
dados = pd.read_csv("C:\\Users\\alcid\\GitHub\\Portfolio\\Airlines Delay\\Airlines.csv")

# %%
dados.head()
# Out:
#    id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  Delay
# 0   1      CO     269         SFO       IAH          3    15     205      1
# 1   2      US    1558         PHX       CLT          3    15     222      1
# 2   3      AA    2400         LAX       DFW          3    20     165      1
# 3   4      AA    2466         SFO       DFW          3    20     195      1
# 4   5      AS     108         ANC       SEA          3    30     202      0

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 539383 entries, 0 to 539382
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id           539383 non-null  int64
#  1   Airline      539383 non-null  object
#  2   Flight       539383 non-null  int64
#  3   AirportFrom  539383 non-null  object
#  4   AirportTo    539383 non-null  object
#  5   DayOfWeek    539383 non-null  int64
#  6   Time         539383 non-null  int64
#  7   Length       539383 non-null  int64
#  8   Delay        539383 non-null  int64
# dtypes: int64(6), object(3)
# memory usage: 37.0+ MB

# %%
dados.isnull().sum().sum()
# Out:
# 0

# %%
dados.duplicated().sum()
# Out:
# 0

# %%
# Analisando a descrição dos dados numéricos
pd.concat([dados.select_dtypes(include=np.number).describe().T,dados.select_dtypes(include=np.number).nunique()], axis=1)
# última coluna expressa os valores únicos.
# Out:
#               count           mean            std   min       25%       50%  \
# id         539383.0  269692.000000  155706.604460   1.0  134846.5  269692.0
# Flight     539383.0    2427.928630    2067.429837   1.0     712.0    1809.0
# DayOfWeek  539383.0       3.929668       1.914664   1.0       2.0       4.0
# Time       539383.0     802.728963     278.045911  10.0     565.0     795.0
# Length     539383.0     132.202007      70.117016   0.0      81.0     115.0
# Delay      539383.0       0.445442       0.497015   0.0       0.0       0.0
#
#                 75%       max       0
# id         404537.5  539383.0  539383
# Flight       3745.0    7814.0    6585
# DayOfWeek       5.0       7.0       7
# Time         1035.0    1439.0    1131
# Length        162.0     655.0     426
# Delay           1.0       1.0       2

# %%
# Analisando a descrição dos dados qualitativos
dados.select_dtypes(exclude=np.number).describe().T
# Out:
#               count unique  top   freq
# Airline      539383     18   WN  94097
# AirportFrom  539383    293  ATL  34449
# AirportTo    539383    293  ATL  34440

# %% [markdown]
# # Análise visual

# %%
# Pela quantidade de categorias, vou transformar esses qualitativos em observar alguma possível relação.
dados_estudo = dados.copy()
for i in dados.select_dtypes(exclude=np.number):
    dados_estudo[i] = LabelEncoder().fit_transform(dados_estudo[i])
    
dados_estudo
# Out:
#             id  Airline  Flight  AirportFrom  AirportTo  DayOfWeek  Time  \
# 0            1        4     269          253        135          3    15
# 1            2       14    1558          217         60          3    15
# 2            3        1    2400          154         80          3    20
# 3            4        1    2466          253         80          3    20
# 4            5        2     108           14        252          3    30
# ...        ...      ...     ...          ...        ...        ...   ...
# 539378  539379        4     178          203        264          5  1439
# 539379  539380        8     398          252         16          5  1439
# 539380  539381        8     609          253        184          5  1439
# 539381  539382       13      78          128        253          5  1439
# 539382  539383       14    1442          154        216          5  1439
#
#         Length  Delay
# 0          205      1
# 1          222      1
# ...

# %%
graficos.correlacao_quan(dado = dados_estudo)

# %% [markdown]
# - O gráfico acima demonstra que não há ligações consideráveis entre o atraso de um vôo e um atributo.

# %% [markdown]
# - Seguindo com a análise, agora deve-se analisar a distribuição dos dados para entender seu comportamento e sua relevância nos dados

# %%
graficos.barras_(dados.select_dtypes(exclude=np.number), "Análise de dispersão qualitativa", (3,1), (10,200))
